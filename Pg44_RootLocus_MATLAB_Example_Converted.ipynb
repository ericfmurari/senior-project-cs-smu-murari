# %%
import numpy as np
import control as c 
import matplotlib.pyplot as plt

# %%
transfer_function = c.TransferFunction([4,3],[1,2,7,25])

# %%
logspace_gains=np.logspace(-1,3,50)
k=np.append(logspace_gains,[3.5])
p1 = c.rlocus(transfer_function,k) 
plt.show() 
plt.axis([-4,1,-20,20])
# Out:
# [-4, 1, -20, 20]
